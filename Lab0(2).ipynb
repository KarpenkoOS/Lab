# %%
import numpy as np
import pprint
import random
np.set_printoptions(precision=5)
pp = pprint.PrettyPrinter(indent=4)

# %%
Q = np.array([[-1, 1, 0, 0],
              [0, -1, 0.5, 0.5],
              [0, 0, -1, 1],
              [1, 0, 0, -1]])

# %%
from scipy.linalg import expm

# %%
expm(Q*10000)
# Out:
# array([[0.28571, 0.28571, 0.14286, 0.28571],
#        [0.28571, 0.28571, 0.14286, 0.28571],
#        [0.28571, 0.28571, 0.14286, 0.28571],
#        [0.28571, 0.28571, 0.14286, 0.28571]])

# %%
def exp_rand(lmbd):
    return -1/lmbd * np.log(random.random()+0.0001)

# %%
def get_state(i):
    p = random.random()
    last = 0
    ans = i
    for j in range(4):
        if last <= p <= last+P[i,j]: 
            ans = j 
            break
        last += P[i,j]
    return ans

# %%
def get_p(i,j):
    if i != j:
        return Q[i,j]/(-Q[i,i])
    else: return 0

# %%
T_max = 10000
P = [[],[],[],[]]
for i in range(4):
    for j in range(4):
        P[i].append(get_p(i,j))
P = np.array(P)
print(P)
cur_state = 0
q = [abs(L[i,i]) for i in range(4)]
times = [exp_rand(q[cur_state]), 0, 0, 0]
cur_time = times[cur_state]

while (cur_time <= T_max):
    cur_state = get_state(cur_state)
    time_in_state = exp_rand(q[cur_state])
    times[cur_state] += time_in_state
    cur_time += time_in_state
    #print(cur_time)
print('\n', times, sum(times))
ans = [item/sum(times) for item in times]
print('\n',ans)
# Out:
# [[0.  1.  0.  0. ]
#  [0.  0.  0.5 0.5]
#  [0.  0.  0.  1. ]
#  [1.  0.  0.  0. ]]
#
#  [2857.745865784133, 2911.457161279558, 1420.2848727582787, 2811.851930393468] 10001.339830215438
#
#  [0.28573630276520406, 0.29110671277098704, 0.1420094604192331, 0.28114752404457577]

# %% [markdown]
# Цепи Маркова с непрерывным временем
